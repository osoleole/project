# %% [markdown]
# Setting up Juputer's working environment for programming, experiments and publishing.
# ===
#
# This article assumes that you already have the working anaconda and jupyter environment.
#
#
# First of all, pandoc and textile converter should be installed.
#
# **`sudo apt-get install pandoc`**
#
# **`sudo apt-get install textlive-full`**
#
#
# After installing **pandoc** we get **nbconvert** that allows convert jupyters notebooks to different formats.
#
#
# Nbconverter docs.
#
# `https://nbconvert.readthedocs.io/en/latest/nbconvert_library.html`
#
# Usefull docs.
#
# `https://github.com/jakevdp/PythonDataScienceHandbook`
#
#
# Nbextensions github.
#
# `https://github.com/ipython-contrib/jupyter_contrib_nbextensions`
#
#
# Installation commands:
# ===
#
# 1. `conda install -c conda-forge jupyter_contrib_nbextensions`
# 2. `jupyter contrib nbextension install --user`
# 3. `conda install -c conda-forge jupyter_nbextensions_configurator`
# 4. `jupyter nbextensions_configurator enable`
# 5. reload `ctr-c` jupyter kernel
# 6. reload jupyter notebook
#
# After all this procesures the new tab named "**Nbextensions**" will appear in the notebooks tree.
#
# Working with extensions
# ===
#
# 1. go to View > Cell Toolbar > Edit Metadata
# 4. click the Edit Metadata button now showing to the top right of the cell
# 5. add 'hide_input':True to the json e.g. mine looked like { "collapsed": false, "hide_input": true, "trusted": true } after
# 6. save notebook
#
# Converting to pdf
# ===
#
# To conver to the notebook to pdf just run
#
# `jupyter nbconvert --to pdf --template printviewlatex.tplx \ Jupyter_presentation.ipynb`

# %% [markdown]
# ## Examples of Latex formulas

# %% [markdown]
# ### Frame formulas
#
# **All frame formulas must be wrapped into following tags:**
#
#
# `
# \begin{equation}
# ...formula...
# \end{equation}
# `
#
# \begin{equation}
# \sum_{i=0}^\infty e^{i\pi} + 1 = 0
# \end{equation}
#
# `\sum_{i=0}^\infty e^{i\pi} + 1 = 0`
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
#
# `e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i`
#
# \begin{equation}
# E = m \cdot c^2
# \end{equation}
#
# `E = m \cdot c^2`
#
# \begin{equation}
# w_{i}^{T}w_{k}=log(P_{ik})=log(X_{ik})-log(X_{i})
# \end{equation}
#
# `w_{i}^{T}w_{k}=log(P_{ik})=log(X_{ik})-log(X_{i})`
#
# \begin{equation}
# \begin{array}{ccc}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{array}
# \end{equation}
#
# `
# \begin{array}{ccc}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{array}
# `
#
# \begin{equation}
# \left[\begin{array}{ccc}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{array}\right]
# \end{equation}
#
# `
# \left[\begin{array}{ccc}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{array}\right]
# `
#
# \begin{equation}
# \intop_{a}^{b}td(t)
# \end{equation}
#
# `\intop_{a}^{b}td(t)`
#
# \begin{equation}
# B\cup A
# \end{equation}
#
# `B\cup A`
#
# \begin{equation}
# \nabla\partial\mathbb{\mathbb{\mathbb{\mathbb{\mathbb{\mathbb{H}C}R}Q}Z}N\exists\forall\top\bot\mathcal{\mathcal{\mathcal{\mathcal{O}H}L}F}}
# \end{equation}
#
# `\nabla\partial\mathbb{\mathbb{\mathbb{\mathbb`
#
# `{\mathbb{\mathbb{H}C}R}Q}Z}N\exists\forall\top`
#
# `\bot\mathcal{\mathcal{\mathcal{\mathcal{O}H}L}F}}`
#
# \begin{equation}
# \alpha\beta\gamma\delta\epsilon\varepsilon\zeta\Delta\Theta\Xi\Pi
# \end{equation}
#
# `\alpha\beta\gamma\delta\epsilon\varepsilon\zeta`
#
# `\Delta\Theta\Xi\Pi`
#
# \begin{equation}
# \pm\cap\oplus\cup\times\otimes\div
# \end{equation}
#
# `\pm\cap\oplus\cup\times\otimes\div`
#
# \begin{equation}
# \leq\geq\equiv\prec\succ\subset\supset\subseteq\supseteq\approx\notin\
# implies\vdash\dashv\land\lor\lnot\iff\perp\ni\in\neq\parallel
# \end{equation}
#
# `\leq\geq\equiv\prec\succ\subset\supset\subseteq`
#
# `\supseteq\approx\notin\implies\vdash\dashv\land`
#
# `\lor\lnot\iff\perp\ni\in\neq\parallel`
#
# \begin{equation}
# \int\sum\prod\coprod\bigsqcup\bigotimes\bigodot\bigoplus\bigcap\bigcup\biguplus\bigvee\bigwedge
# \end{equation}
#
# `\int\sum\prod\coprod\bigsqcup\bigotimes\bigodot`
#
# `\bigoplus\bigcap\bigcup\biguplus\bigvee\bigwedge`
#
# \begin{equation}
# \widetilde{p}\overbrace{asd}\vec{wer}\check{q}\breve{R}\overleftrightarrow{E}
# \end{equation}
#
# `\widetilde{p}\overbrace{asd}\vec{wer}\check{q}`
#
# `\breve{R}\overleftrightarrow{E}`
#
#
# \begin{equation}
# \arccos-\tanh=\lim_{i\rightarrow\infty}+\sup\left\{ A,D\right\}
# \end{equation}
#
# `\arccos-\tanh=\lim_{i\rightarrow\infty}+\sup\left\{ A,D\right\}`
#
# \begin{equation}
# \begin{cases}
# \begin{array}{c}
# x<3\\
# x=3\\
# x>3
# \end{array} & \begin{array}{c}
# 8\\
# 11\\
# 90
# \end{array}\end{cases}
# \end{equation}
#
# `
# \begin{cases}
# \begin{array}{c}
# x<3\\
# x=3\\
# x>3
# \end{array} & \begin{array}{c}
# 8\\
# 11\\
# 90
# \end{array}\end{cases}
# `
#
# \begin{equation}
# \sum_{i=0}^{N}\frac{PlnP}{\sum_{i=k}^{N}}
# \end{equation}
#
# `\sum_{i=0}^{N}\frac{PlnP}{\sum_{i=k}^{N}}`
#
# \begin{equation}
# \sqrt[2]{ln(P)^{2}-ln(P_{i})^{2}}
# \end{equation}
#
# `\sqrt[2]{ln(P)^{2}-ln(P_{i})^{2}}`
#
#
# \begin{equation}
# P(A|B)=\frac{P(B|A)P(A)}{P(B)}
# \end{equation}
#
# `P(A|B)=\frac{P(B|A)P(A)}{P(B)}`
#
#
# ### Inline formulas
#
# Inline formulae $\sum_{i}^{N}A^{T}W$
#
# `Inline formulae $\sum_{i}^{N}A^{T}W$`
