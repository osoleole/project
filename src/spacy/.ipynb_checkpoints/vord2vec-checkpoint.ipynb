# %%
import os
import pickle
import spacy
import pandas as pd
import settings

# %% [markdown]
# # Distributed vector representation model

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence

# %%
NORMALIZED_TEXT_FILE_NAME = 'normalized_text.txt'
normalized_text_file = os.path.join(settings.NORMALIZED_DATA_PATH, NORMALIZED_TEXT_FILE_NAME)

# %%
# Load normalized text
normalized_text = LineSentence(normalized_text_file)
# Path where model will be saved
word2vec_filepath = os.path.join(settings.NORMALIZED_DATA_PATH, 'word2vec_model')

# %% [markdown]
# ### Start word2vec model training. Set vector dimension and epochs number.

# %%
# Run it to retrain our model. Model will be saved in "word2vec_filepath"
# Most important training parameters:
# size - word vector dimension
# window - context size

# Training parameters
# Word vector dimension 
vector_dim = 100
# Context size
context_size = 5
# Training epochs
epochs = 20

# Make False to use pretraind models
if True:
    # Take trigram text and start first epoch
    text2vec = Word2Vec(normalized_text, size=vector_dim, window=context_size,
                        min_count=20, sg=1, workers=4)
    # Save first iteration 
    text2vec.save(word2vec_filepath)
    # Train another epochs and save model in "word2vec_filepath"
    for i in range(1,epochs):
        text2vec.train(normalized_text)
        print("Tis is epoch N-{}".format(i))
        text2vec.save(word2vec_filepath)

# %% [markdown]
# ### Load trained word2vec model

# %%
# Load vector representation from trained 'word2vec_model'
text2vec = Word2Vec.load(word2vec_filepath)
text2vec.init_sims()

# Shows number of training epochs
print('{} training epochs.'.format(text2vec.train_count))
# Out:
# 20 training epochs.

# %% [markdown]
# ### Convert text word2vector to panda's data frame

# %%
# Create list of word2vector tuples
ordered_vocab = [(term, voc.index, voc.count)
                 for term, voc in text2vec.vocab.items()]

# Sort oredred vocab by voc.count
ordered_vocab = sorted(ordered_vocab, key=lambda count: count[2]) # try to use -count[2]

# Make three lists of: terms, indices, counts
ordered_terms, term_indices, term_counts = zip(*ordered_vocab)

# Create panda's data frame of word vector representation
word_vectors = pd.DataFrame(text2vec.syn0norm[term_indices, :],
                            index=ordered_terms)

# %%
word_vectors[1:50]
# Out:
#                                          0         1         2         3   \
# licensee                           0.031852  0.019403 -0.097552 -0.038575
# smith_moore_leatherwood_llp        0.004333 -0.182786  0.085152 -0.168357
# ktla                               0.036297 -0.109484 -0.194115  0.053863
# land_building                      0.153641 -0.061031  0.006827  0.115745
# obligatory                         0.043459 -0.250421  0.030282  0.031152
# broadcasting_segment              -0.032649 -0.020780 -0.054819  0.029976
# multi                              0.021568 -0.071260  0.026943 -0.014172
# proposal                          -0.128872 -0.065134  0.014567  0.207158
# phones                            -0.064605 -0.065115  0.046106  0.107942
# mct                                0.075137 -0.003903 -0.068790  0.207596
# go_concern                        -0.045229 -0.068681 -0.004681 -0.082298
# local_news                         0.066796 -0.251189 -0.108943  0.094618
# launch                             0.043061  0.033268 -0.101605  0.059647
# write_affirmation                  0.028758  0.078755 -0.160515  0.089057
# 70                                -0.219732 -0.127712  0.197250  0.032400
# 08                                 0.049806 -0.197269  0.107929  0.079638
# pease_llp                          0.015446 -0.235686  0.054508 -0.168457
# 100_f_street_n.e.                 -0.164762 -0.067967  0.131128 -0.051995
# 501_n._orange_holdco               0.054825 -0.100001 -0.282542 -0.087926
# tribune_studios                   -0.045721 -0.048344 -0.097993  0.039742
# third_circuit                     -0.049985 -0.284280  0.026941 -0.120386
# decide                            -0.048835 -0.049127  0.028934  0.051728
# sale/leaseback                    -0.272255 -0.145604  0.007248  0.051821
# limitations                       -0.173508 -0.235055 -0.036816 -0.054479
# train                             -0.019215 -0.282993  0.070197 -0.183899
# smith_incorporated                 0.028213 -0.133595 -0.202760 -0.053342
# backup_withholding                -0.019046 -0.231324  0.088663  0.170231
# unresolved_claim                  -0.091331 -0.201310 -0.106763  0.023627
# south_carolina                    -0.015353 -0.264415 -0.147372 -0.002628
# yet_delinquent                     0.011154 -0.160391 -0.145439  0.086341
# enterprise_nonprofit_entity        0.081679 -0.009416 -0.157644  0.048435
# plaintiff                          0.026678 -0.211941  0.034763 -0.011207
# bridge                            -0.009864 -0.040563  0.075971  0.032973
# 329.3                             -0.076850 -0.200451  0.173374  0.003178
# 400                               -0.156070 -0.065650  0.046155  0.024337
# wdaf_license                       0.193695 -0.160911 -0.055290 -0.211683
# sport_programming                  0.076261  0.057399 -0.072056 -0.032619
# unexpired_lease                   -0.054796 -0.147024  0.002536 -0.038242
# rsmo                               0.027558 -0.231978 -0.271985 -0.020458
# asu_2014_09                        0.088086 -0.025365 -0.050437  0.077617
# 187                               -0.200929 -0.082130 -0.105439  0.116554
# pre_need                          -0.077800 -0.072591 -0.125602 -0.136198
# nybcl                              0.063638 -0.087477 -0.019086  0.106560
# consolidation_merger_amalgamation -0.096174 -0.190574  0.120610 -0.080935
# whose_functional_currency         -0.006314 -0.164574 -0.060377  0.022428
# memorial_park                     -0.004748 -0.134701 -0.151115 -0.089873
# wpix                               0.114648 -0.144952 -0.251521  0.019256
# nielsen                            0.153250 -0.181599 -0.017902  0.072694
# profits                           -0.062691 -0.192951  0.155522 -0.049768
#
#                                          4         5         6         7   \
# licensee                          -0.041155  0.098296  0.010953  0.146101
# smith_moore_leatherwood_llp       -0.007947 -0.048193  0.009030 -0.089799
# ktla                               0.018302  0.056144 -0.231593  0.048295
# land_building                      0.046312 -0.201267 -0.133011 -0.033139
# obligatory                        -0.025840  0.038683 -0.189824  0.171932
# broadcasting_segment              -0.049132  0.110964 -0.063405  0.129736
# multi                              0.058215 -0.007215 -0.022585  0.121711
# proposal                           0.065669 -0.024745 -0.070250 -0.011820
# phones                            -0.177545 -0.072098 -0.112624  0.027657
# mct                                0.009695 -0.052115 -0.103006  0.148466
# go_concern                         0.023345  0.021900  0.148743  0.036281
# local_news                         0.041423  0.016388 -0.030042 -0.011799
# launch                             0.128101 -0.017373 -0.108811  0.066699
# write_affirmation                  0.039252 -0.080558 -0.146331  0.126115
# 70                                 0.087312 -0.180926 -0.126153  0.139380
# 08                                 0.041343  0.003780 -0.173951  0.005215
# pease_llp                          0.015605 -0.095480  0.055108 -0.128237
# 100_f_street_n.e.                 -0.003606 -0.065795 -0.066680  0.236744
# 501_n._orange_holdco               0.011820  0.056128 -0.188411 -0.009672
# tribune_studios                    0.020034 -0.056031 -0.155142 -0.173161
# third_circuit                      0.008529 -0.025553 -0.100644  0.032584
# decide                            -0.145170 -0.075353  0.046614 -0.158501
# sale/leaseback                    -0.079810 -0.160483  0.026912  0.038869
# limitations                       -0.052686 -0.121511  0.057574 -0.037253
# train                              0.131060 -0.011584 -0.085991 -0.002078
# smith_incorporated                 0.058978 -0.093303 -0.092550  0.064787
# backup_withholding                -0.059788 -0.008681 -0.024221 -0.135623
# unresolved_claim                  -0.146472  0.126524 -0.032050  0.049924
# south_carolina                     0.086638  0.068120 -0.095860  0.027581
# yet_delinquent                     0.032275  0.030493  0.011005  0.110979
# enterprise_nonprofit_entity       -0.036497  0.011387 -0.098830  0.032713
# plaintiff                          0.036310  0.125110 -0.116459 -0.027948
# bridge                             0.018172  0.131052 -0.194760  0.044913
# 329.3                              0.007648  0.034639 -0.068495 -0.064498
# 400                               -0.026626  0.052767 -0.033791 -0.014634
# wdaf_license                      -0.108934 -0.032656 -0.115917 -0.092102
# sport_programming                 -0.031826 -0.126849 -0.021932 -0.044665
# unexpired_lease                   -0.031731  0.024534 -0.069953 -0.007906
# rsmo                               0.040799 -0.192364 -0.021830  0.088562
# asu_2014_09                        0.037318  0.023735 -0.044804  0.138549
# 187                                0.124810  0.128153 -0.053895  0.246244
# pre_need                           0.084714  0.078325 -0.023536  0.114980
# nybcl                             -0.020024 -0.098250 -0.062605  0.116881
# consolidation_merger_amalgamation -0.052765 -0.026992 -0.093431 -0.065352
# whose_functional_currency         -0.132631 -0.001772 -0.029650 -0.050063
# memorial_park                      0.020612 -0.095577  0.039530  0.020900
# wpix                              -0.015299  0.124555 -0.183137  0.045539
# nielsen                            0.014768  0.016455  0.078528  0.009806
# profits                           -0.182994 -0.001719 -0.027596  0.166617
#
#                                          8         9     ...           90  \
# licensee                           0.158197  0.113200    ...    -0.073482
# smith_moore_leatherwood_llp        0.108670 -0.038184    ...    -0.147976
# ktla                               0.037637  0.121789    ...     0.115552
# land_building                     -0.017308  0.077886    ...     0.073858
# obligatory                        -0.057210 -0.094105    ...    -0.047514
# broadcasting_segment              -0.119845  0.017012    ...     0.035264
# multi                              0.048283  0.006675    ...    -0.015075
# proposal                          -0.141841 -0.147899    ...     0.150639
# phones                             0.078143  0.062857    ...     0.150285
# mct                                0.090710 -0.272532    ...    -0.095807
# go_concern                         0.113370 -0.096822    ...    -0.016534
# local_news                         0.090127 -0.006658    ...    -0.059726
# launch                             0.101309  0.051695    ...    -0.023670
# write_affirmation                 -0.059593 -0.005671    ...     0.017796
# 70                                 0.004919  0.017763    ...    -0.118035
# 08                                -0.010646 -0.158956    ...     0.082390
# pease_llp                          0.123626 -0.048403    ...    -0.120073
# 100_f_street_n.e.                  0.087524 -0.037125    ...    -0.142862
# 501_n._orange_holdco               0.028052  0.072302    ...    -0.032508
# tribune_studios                    0.049726  0.036472    ...     0.053314
# third_circuit                      0.040045 -0.072830    ...     0.019276
# decide                             0.105167  0.013041    ...     0.108107
# sale/leaseback                    -0.095215  0.055511    ...    -0.010136
# limitations                        0.065081 -0.122913    ...    -0.030319
# train                             -0.039605 -0.069959    ...     0.005570
# smith_incorporated                 0.073786  0.052499    ...    -0.001908
# backup_withholding                -0.033099  0.061140    ...     0.033966
# unresolved_claim                   0.043521  0.024430    ...    -0.025682
# south_carolina                    -0.010221  0.028932    ...     0.067839
# yet_delinquent                    -0.007850  0.057454    ...    -0.045448
# enterprise_nonprofit_entity        0.041806  0.056576    ...     0.170856
# plaintiff                          0.104543 -0.135963    ...    -0.051876
# bridge                             0.096535  0.004500    ...     0.065098
# 329.3                             -0.153647  0.130793    ...    -0.037824
# 400                                0.095857  0.174303    ...     0.029365
# wdaf_license                       0.093892 -0.086137    ...    -0.117933
# sport_programming                  0.044369  0.040971    ...     0.083613
# unexpired_lease                   -0.011410 -0.032487    ...     0.002846
# rsmo                               0.016567  0.065905    ...    -0.095440
# asu_2014_09                        0.117619  0.085120    ...     0.049359
# 187                                0.032197  0.205658    ...    -0.021022
# pre_need                           0.000538  0.111375    ...    -0.017100
# nybcl                              0.048993  0.027342    ...    -0.079974
# consolidation_merger_amalgamation  0.126069  0.119016    ...    -0.049127
# whose_functional_currency          0.077469 -0.035091    ...     0.005133
# memorial_park                     -0.043499 -0.152930    ...    -0.143805
# wpix                               0.108834  0.030582    ...     0.057500
# nielsen                           -0.007067  0.068210    ...    -0.109976
# profits                            0.135104  0.083819    ...     0.015895
#
#                                          91        92        93        94  \
# licensee                           0.042011 -0.070181 -0.041359  0.019073
# smith_moore_leatherwood_llp        0.075361 -0.208663  0.064516 -0.119285
# ktla                               0.073199 -0.143269 -0.079307  0.214425
# land_building                      0.112958  0.114405  0.066535  0.167094
# obligatory                         0.013574 -0.069723 -0.021799 -0.063731
# broadcasting_segment               0.018775 -0.067737 -0.014907  0.204278
# multi                              0.216692  0.144236 -0.217891  0.033411
# proposal                           0.340918  0.039162  0.006713 -0.023356
# phones                            -0.042596  0.222061  0.046646 -0.028490
# mct                                0.118440 -0.183096 -0.011689 -0.006163
# go_concern                         0.086654  0.036965  0.077020 -0.052817
# local_news                         0.244184 -0.106478  0.166797 -0.028112
# launch                             0.066523 -0.073671 -0.134919  0.099625
# write_affirmation                  0.194302 -0.119028 -0.136894  0.075298
# 70                                 0.193734 -0.005161  0.084970  0.012478
# 08                                 0.154284  0.112239  0.014383  0.165531
# pease_llp                          0.075459 -0.165657  0.056390 -0.093967
# 100_f_street_n.e.                  0.089587 -0.079430 -0.011303 -0.007723
# 501_n._orange_holdco              -0.047210  0.022661  0.024877  0.113918
# tribune_studios                    0.001977  0.021694  0.121255 -0.019718
# third_circuit                      0.096794 -0.052344 -0.038470 -0.041469
# decide                             0.077748 -0.084582  0.020719  0.089796
# sale/leaseback                     0.048988  0.061836  0.151469  0.157322
# limitations                       -0.018932 -0.127109  0.012032  0.056354
# train                              0.071272  0.041749  0.003978 -0.004467
# smith_incorporated                -0.038972  0.015807  0.006235 -0.100019
# backup_withholding                 0.141623 -0.017153  0.172785 -0.052387
# unresolved_claim                  -0.083718 -0.001925 -0.006457  0.038388
# south_carolina                    -0.002533 -0.069938 -0.181062  0.211267
# yet_delinquent                    -0.038097  0.035746  0.011615  0.047069
# enterprise_nonprofit_entity       -0.156945  0.072917 -0.080864  0.051821
# plaintiff                          0.088173 -0.003969 -0.150501 -0.044551
# bridge                             0.144860  0.124073  0.132261  0.197512
# 329.3                              0.079112 -0.107907  0.076114  0.009216
# 400                                0.111978 -0.008633  0.134029 -0.034227
# wdaf_license                       0.118248  0.028998 -0.055687  0.048452
# sport_programming                 -0.037947  0.072722 -0.098776 -0.024527
# unexpired_lease                    0.024237 -0.058499 -0.020945  0.199832
# rsmo                              -0.064764 -0.037811 -0.024060  0.153655
# asu_2014_09                        0.065817  0.040242  0.004840  0.100436
# 187                                0.023029  0.044147  0.049165  0.007297
# pre_need                           0.021908  0.093067  0.025521  0.077059
# nybcl                              0.035918 -0.064962 -0.202064 -0.131436
# consolidation_merger_amalgamation -0.187953 -0.032459  0.069264  0.101977
# whose_functional_currency          0.100284 -0.078992  0.072426 -0.052284
# memorial_park                      0.143446 -0.092620  0.110740  0.036794
# wpix                              -0.003048 -0.112767 -0.077031  0.139654
# nielsen                            0.010556 -0.031077  0.114861  0.084321
# profits                            0.014299 -0.161825 -0.019592  0.065734
#
#                                          95        96        97        98  \
# licensee                          -0.197888 -0.016013  0.020854 -0.090580
# smith_moore_leatherwood_llp       -0.019405 -0.126509 -0.197764 -0.062363
# ktla                               0.123593  0.017560 -0.025347 -0.115492
# land_building                      0.080539 -0.203460  0.034857 -0.147164
# obligatory                        -0.133714 -0.225109 -0.073817  0.020206
# broadcasting_segment               0.040504  0.043438  0.025313 -0.038630
# multi                             -0.073512 -0.144628 -0.072741 -0.101999
# proposal                          -0.204673 -0.001672 -0.074338 -0.081880
# phones                            -0.089464  0.062914  0.141921 -0.111336
# mct                               -0.147188  0.102247  0.182102  0.081169
# go_concern                         0.010676 -0.136443 -0.050280  0.139052
# local_news                         0.118977 -0.126597  0.066016  0.058212
# launch                            -0.051426 -0.276645 -0.034017 -0.015495
# write_affirmation                 -0.012191  0.010463  0.008018 -0.002595
# 70                                 0.035339 -0.053040 -0.037681 -0.033468
# 08                                -0.085872 -0.158756 -0.033880 -0.084218
# pease_llp                         -0.021826 -0.099031 -0.196680 -0.088665
# 100_f_street_n.e.                 -0.086434 -0.107433  0.002961 -0.018886
# 501_n._orange_holdco               0.046757 -0.087347 -0.089679  0.018067
# tribune_studios                    0.022389 -0.099028  0.116482  0.002704
# third_circuit                      0.009082 -0.165236  0.006187 -0.090288
# decide                            -0.246824 -0.041884  0.158247 -0.040148
# sale/leaseback                    -0.058348 -0.094422 -0.077775 -0.113209
# limitations                       -0.151328 -0.090805 -0.001427 -0.022400
# train                             -0.003145 -0.035880  0.089962  0.033925
# smith_incorporated                 0.019345 -0.082135  0.051396 -0.111641
# backup_withholding                -0.096570  0.049168  0.022200  0.047374
# unresolved_claim                   0.025797  0.085052  0.043783 -0.057098
# south_carolina                    -0.092406 -0.063131  0.002854 -0.121255
# yet_delinquent                    -0.085095 -0.010567 -0.198339  0.031664
# enterprise_nonprofit_entity       -0.192502 -0.032518 -0.055288 -0.043546
# plaintiff                          0.143426 -0.125844  0.017707  0.048043
# bridge                             0.036350  0.176454  0.056760 -0.017381
# 329.3                             -0.035687 -0.116981  0.102595 -0.193725
# 400                               -0.076820 -0.221835  0.229886 -0.186475
# wdaf_license                       0.015836 -0.077225 -0.091767 -0.041645
# sport_programming                  0.009830 -0.078969  0.174701  0.002712
# unexpired_lease                    0.113601  0.112820  0.046049 -0.155192
# rsmo                              -0.162216 -0.126625 -0.020453 -0.150501
# asu_2014_09                       -0.166560 -0.073724 -0.038642 -0.174762
# 187                               -0.103046 -0.132235  0.038515 -0.101759
# pre_need                           0.037158  0.011687  0.164074 -0.025429
# nybcl                             -0.036930 -0.074271 -0.012777  0.087832
# consolidation_merger_amalgamation -0.059788 -0.176380  0.011791 -0.129650
# whose_functional_currency         -0.118961  0.061366 -0.051484  0.113847
# memorial_park                     -0.079442 -0.145774  0.010977 -0.054804
# wpix                               0.116331 -0.016035 -0.008776 -0.129690
# nielsen                           -0.133265 -0.065410  0.126331 -0.008539
# profits                           -0.101639  0.065228  0.031648  0.133333
#
#                                          99
# licensee                           0.075486
# smith_moore_leatherwood_llp       -0.010732
# ktla                               0.030550
# land_building                      0.001367
# obligatory                        -0.010243
# broadcasting_segment               0.024217
# multi                             -0.045995
# proposal                          -0.002166
# phones                            -0.083787
# mct                                0.144527
# go_concern                        -0.042560
# local_news                        -0.134082
# launch                            -0.029827
# write_affirmation                 -0.060454
# 70                                 0.071726
# 08                                 0.097357
# pease_llp                         -0.008611
# 100_f_street_n.e.                  0.040305
# 501_n._orange_holdco              -0.052140
# tribune_studios                   -0.027625
# third_circuit                     -0.025186
# decide                             0.048233
# sale/leaseback                     0.010574
# limitations                        0.096324
# train                              0.133616
# smith_incorporated                -0.058773
# backup_withholding                 0.086260
# unresolved_claim                   0.084588
# south_carolina                     0.039005
# yet_delinquent                     0.069830
# enterprise_nonprofit_entity       -0.012817
# plaintiff                         -0.080303
# bridge                            -0.182107
# 329.3                              0.068587
# 400                                0.027630
# wdaf_license                      -0.052372
# sport_programming                  0.052293
# unexpired_lease                    0.224128
# rsmo                              -0.007400
# asu_2014_09                        0.015275
# 187                               -0.085033
# pre_need                          -0.126358
# nybcl                             -0.155901
# consolidation_merger_amalgamation  0.029892
# whose_functional_currency          0.060543
# memorial_park                     -0.102774
# wpix                              -0.009547
# nielsen                            0.029515
# profits                            0.003775
#
# [49 rows x 100 columns]

# %% [markdown]
# ### Words similarity function

# %%
# Get similar/realated word in context
def get_context_related_words(token, topn=10):
    '''Returns topn context related words as a dictionary'''
    word_sim = {}
    for word, similarity in text2vec.most_similar(positive=[token], topn=topn):
        word_sim.update({word:similarity})
    return word_sim

# %% [markdown]
# #### Testing model's performance. Trying to find semantially close words and phrases.
#
# Find semantically close words to word 'cost'

# %%
get_context_related_words('cost', topn=20)
# Out:
# {'153.7': 0.38838207721710205,
#  '2,472.9': 0.42199376225471497,
#  '2,494.1': 0.4554964601993561,
#  '27.7': 0.48493120074272156,
#  '3,663.0': 0.4689284861087799,
#  'amortize': 0.5120112895965576,
#  'brokerage': 0.39271965622901917,
#  'deferred': 0.3934595584869385,
#  'discount': 0.40827229619026184,
#  'expense': 0.44802170991897583,
#  'expensing': 0.39666426181793213,
#  'extraordinary': 0.39504194259643555,
#  'gain': 0.3928598165512085,
#  'human_resource': 0.43243271112442017,
#  'legal': 0.414577454328537,
#  'obstacle': 0.397826224565506,
#  'pricing': 0.40854325890541077,
#  'recognition': 0.4200395345687866,
#  'retrospective_adoption_approximately': 0.4277220666408539,
#  'technology': 0.39840424060821533}

# %% [markdown]
# ### Words meanings linear algebra function

# %%
def word_algebra(add=[], subtract=[], topn=1):
    '''Returns topn words as the result of operations 
    add=['token1','token2']
    subtract=['token1','token2']
    '''
    answers = text2vec.most_similar(positive=add, negative=subtract, topn=topn)
    for term, similarity in answers:
        print(term)

# %% [markdown]
# ## t-SNE Distributed stochastic neighbor embedding
# Map high dimensional data to low dimensions 2 or 3

# %%
from sklearn.manifold import TSNE

# %%
# Number of vectors to apply t-SNE 
tsne_vectors = 600

# Take data from panda's data frame. Remove stopwords from it.
tsne_input = word_vectors.drop(spacy.en.STOPWORDS, errors=u'ignore')

# Take the vectors  
tsne_input = tsne_input.head(tsne_vectors)

# Path to save model in binary file 'tsne_model'
tsne_filepath = os.path.join(settings.DATA_PATH, 'tsne_model')

# Path to save vectors in binary file 'tsne_model'
tsne_vectors_filepath = os.path.join(settings.DATA_PATH, 'tsne_vectors.npy')

# %% [markdown]
# ### t-SNE training

# %%
# Trains t-SNE dimension reduction. !!!Check additional twicks.
# Saves t-sne model in file 'tsne_filepath'
# Saves t-sne vectors in file 'tsne_vectors_filepath'
if True:
    tsne = TSNE()
    tsne_vectors = tsne.fit_transform(tsne_input.values)
    with open(tsne_filepath, 'wb') as f:
        pickle.dump(tsne, f)
    pd.np.save(tsne_vectors_filepath, tsne_vectors)

# %% [markdown]
# ### Load pretrained t-SNE model

# %%
# Loads t-SNE models
with open(tsne_filepath, 'rb') as f:
    tsne = pickle.load(f)

# Loads t-SNE vectors from 'tsne_vectors_filepath'
tsne_vectors = pd.np.load(tsne_vectors_filepath)

# Converts tsne_vectors to panda's data frame
tsne_vectors = pd.DataFrame(tsne_vectors,
                            index=pd.Index(tsne_input.index),
                            columns=[u'x_coord', u'y_coord'])

# %%
# Just shows everyting is OK.
tsne_vectors.head()
# Out:
#                 x_coord    y_coord
# work_capital   2.273404  10.040244
# in_most_case  14.516599   4.917390
# socalled       9.111805   4.795907
# component     23.652160   3.793310
# scope        -24.871328  -5.657409

# %%
# Just renames field of panda's data frame 
tsne_vectors['word'] = tsne_vectors.index

# %% [markdown]
# ## Plot t-SNE data

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()

# %%
# Add tsne_vectors from DataFrame to bokeh as ColumnDataSource 
plot_data = ColumnDataSource(tsne_vectors)

# Create plot
tsne_plot = figure(title='Word embeddings for M&A domain vector space',
                   plot_width = 800,
                   plot_height = 800,
                   tools= ('pan, wheel_zoom, box_zoom,'
                           'box_select, resize, reset'),
                   active_scroll='wheel_zoom')

# Add hover tool to plot
tsne_plot.add_tools(HoverTool(tooltips = '@word'))

# Plot words as circle
tsne_plot.circle('x_coord', 'y_coord', source=plot_data,
                 color='blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color='black')
# Title
tsne_plot.title.text_font_size = value('16pt')

# Axis parameters
tsne_plot.xaxis.visible = False
tsne_plot.yaxis.visible = False
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None
