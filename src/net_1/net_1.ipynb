# %%
import numpy as np
import pickle
import time
from ipywidgets import interact
from bokeh.io import push_notebook
from bokeh.plotting import figure, output_file, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2c501841-3e8b-4189-8b6e-5f8cdb8d031e">Loading BokehJS ...</span>
#     </div>

# %%
ra1 = np.random.rand(2,2)
ra2 = np.array([1,2])
ray = np.dot(ra1,ra2)
xc = [0,ray[0]]
yc = [0,ray[1]]

print("X-{}: Y-{}".format(xc,yc))
# Out:
# X-[0, 0.81959980698418256]: Y-[0, 1.0749005052804588]

# %%
p = figure(title="line", plot_width=450, plot_height=450, y_range=[0.0,3.0], x_range=[0.0,3.0], webgl=True)
r = p.line(xc,yc)

def update():
    ra1 = np.random.rand(2,2)
    ra2 = np.array([1,2])
    ray = np.dot(ra1,ra2)
    xc = [0,ray[0]]
    yc = [0,ray[1]]
    r.data_source.data['y'] = yc
    r.data_source.data['x'] = xc
    push_notebook()

show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9ab33fe9-407d-440e-9fd2-c6ac3088ef21"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9ab33fe9-407d-440e-9fd2-c6ac3088ef21").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("40d434f0-c95e-43a6-a0dc-7d6e11a288db", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ab33fe9-407d-440e-9fd2-c6ac3088ef21");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ab33fe9-407d-440e-9fd2-c6ac3088ef21' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a93c559c-78bb-489b-a42c-33fb106485ee":{"roots":{"references":[{"attributes":{},"id":"2763cd1d-503a-4d12-967a-c43d60cd007c","type":"BasicTicker"},{"attributes":{"plot":null,"text":"line"},"id":"0a93d650-8ba5-4e3a-8ac3-cd8cc27da3ee","type":"Title"},{"attributes":{"plot":{"id":"46842513-d4af-4d2a-bfb7-de1813133859","subtype":"Figure","type":"Plot"}},"id":"7ce0b16f-380d-43a4-9d34-db3170b2d3d6","type":"SaveTool"},{"attributes":{"data_source":{"id":"b19c3684-5704-4484-9ce0-b2abef635b21","type":"ColumnDataSource"},"glyph":{"id":"7ca26712-3aca-4ff8-88da-c0d275d35202","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"305a4f0d-91cb-49a8-b4dd-7475d236350f","type":"Line"},"selection_glyph":null},"id":"ed910bf1-1c09-4c8f-aa0d-6a3d2f2523d3","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":3.0},"id":"6d4c6257-1a13-45e0-91d8-23e3399f07eb","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2cfee09d-2c63-45eb-a862-1ed55699da0f","type":"PanTool"},{"id":"53b61fe5-1f17-45e6-90fa-ef252215c037","type":"WheelZoomTool"},{"id":"cf4c7713-e7e6-46f4-81a0-e33f4c5381a8","type":"BoxZoomTool"},{"id":"7ce0b16f-380d-43a4-9d34-db3170b2d3d6","type":"SaveTool"},{"id":"64350cb5-e4ad-4282-a41d-a01f419ec483","type":"ResetTool"},{"id":"266677bf-05eb-4717-b238-a4277dbfab6e","type":"HelpTool"}]},"id":"ae62a013-47c5-4a35-9c4a-126db88a8755","type":"Toolbar"},{"attributes":{},"id":"20c87de2-2805-46f0-afc9-fe77a6519de0","type":"ToolEvents"},{"attributes":{},"id":"4ca1b3f8-2b77-4fa6-8ee1-971ef2c0e823","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"305a4f0d-91cb-49a8-b4dd-7475d236350f","type":"Line"},{"attributes":{"plot":{"id":"46842513-d4af-4d2a-bfb7-de1813133859","subtype":"Figure","type":"Plot"}},"id":"53b61fe5-1f17-45e6-90fa-ef252215c037","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":3.0},"id":"44a27d71-e554-4e56-bb84-92ab90e80434","type":"Range1d"},{"attributes":{"below":[{"id":"be6c4d3b-4f3b-4145-b710-1e1b41bc975b","type":"LinearAxis"}],"left":[{"id":"7ae5c108-f01a-4525-a076-a52af4ff1951","type":"LinearAxis"}],"plot_height":450,"plot_width":450,"renderers":[{"id":"be6c4d3b-4f3b-4145-b710-1e1b41bc975b","type":"LinearAxis"},{"id":"be79dcdb-3327-4072-bcb7-1ee350e1745f","type":"Grid"},{"id":"7ae5c108-f01a-4525-a076-a52af4ff1951","type":"LinearAxis"},{"id":"7748a749-71b9-4a71-b0bd-a00abe6ae2bc","type":"Grid"},{"id":"ab8b9631-3ba6-4ca1-92f2-3362a8f5b170","type":"BoxAnnotation"},{"id":"ed910bf1-1c09-4c8f-aa0d-6a3d2f2523d3","type":"GlyphRenderer"}],"title":{"id":"0a93d650-8ba5-4e3a-8ac3-cd8cc27da3ee","type":"Title"},"tool_events":{"id":"20c87de2-2805-46f0-afc9-fe77a6519de0","type":"ToolEvents"},"toolbar":{"id":"ae62a013-47c5-4a35-9c4a-126db88a8755","type":"Toolbar"},"webgl":true,"x_range":{"id":"44a27d71-e554-4e56-bb84-92ab90e80434","type":"Range1d"},"y_range":{"id":"6d4c6257-1a13-45e0-91d8-23e3399f07eb","type":"Range1d"}},"id":"46842513-d4af-4d2a-bfb7-de1813133859","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"b0836093-c8c6-41b1-a565-7dd7dfae9342","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.8195998069841826],"y":[0.0,1.0749005052804588]}},"id":"b19c3684-5704-4484-9ce0-b2abef635b21","type":"ColumnDataSource"},{"attributes":{},"id":"df1711a4-7765-46e4-89be-cb906a5db539","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7ca26712-3aca-4ff8-88da-c0d275d35202","type":"Line"},{"attributes":{"plot":{"id":"46842513-d4af-4d2a-bfb7-de1813133859","subtype":"Figure","type":"Plot"}},"id":"2cfee09d-2c63-45eb-a862-1ed55699da0f","type":"PanTool"},{"attributes":{"plot":{"id":"46842513-d4af-4d2a-bfb7-de1813133859","subtype":"Figure","type":"Plot"}},"id":"266677bf-05eb-4717-b238-a4277dbfab6e","type":"HelpTool"},{"attributes":{"formatter" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[44]</strong>&gt;</code></p>

# %%
for i in range(30):
    time.sleep(0.5)
    update()
